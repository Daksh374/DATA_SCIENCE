# %%
import sys
# !{sys.executable} -m pip install sweetviz
# Out:
# Collecting sweetviz
#   Using cached sweetviz-2.3.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /Users/dakshyadav/Desktop/DATA_SCIENCE/.venv/lib/python3.14/site-packages (from sweetviz) (3.0.3)
# Requirement already satisfied: numpy>=1.16.0 in /Users/dakshyadav/Desktop/DATA_SCIENCE/.venv/lib/python3.14/site-packages (from sweetviz) (2.5.1)
# Requirement already satisfied: matplotlib>=3.1.3 in /Users/dakshyadav/Desktop/DATA_SCIENCE/.venv/lib/python3.14/site-packages (from sweetviz) (3.11.1)
# Collecting tqdm>=4.43.0 (from sweetviz)
#   Downloading tqdm-4.70.0-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: scipy>=1.3.2 in /Users/dakshyadav/Desktop/DATA_SCIENCE/.venv/lib/python3.14/site-packages (from sweetviz) (1.18.0)
# Requirement already satisfied: jinja2>=2.11.1 in /Users/dakshyadav/Desktop/DATA_SCIENCE/.venv/lib/python3.14/site-packages (from sweetviz) (3.1.6)
# Collecting importlib_resources>=1.2.0 (from sweetviz)
#   Downloading importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dakshyadav/Desktop/DATA_SCIENCE/.venv/lib/python3.14/site-packages (from jinja2>=2.11.1->sweetviz) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dakshyadav/Desktop/DATA_SCIENCE/.venv/lib/python3.14/site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/dakshyadav/Desktop/DATA_SCIENCE/.venv/lib/python3.14/site-packages (from matplotlib>=3.1.3->sweetviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /Users/dakshyadav/Desktop/DATA_SCIENCE/.venv/lib/python3.14/site-packages (from matplotlib>=3.1.3->sweetviz) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/dakshyadav/Desktop/DATA_SCIENCE/.venv/lib/python3.14/site-packages (from matplotlib>=3.1.3->sweetviz) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/dakshyadav/Desktop/DATA_SCIENCE/.venv/lib/python3.14/site-packages (from matplotlib>=3.1.3->sweetviz) (26.2)
# Requirement already satisfied: pillow>=9 in /Users/dakshyadav/Desktop/DATA_SCIENCE/.venv/lib/python3.14/site-packages (from matplotlib>=3.1.3->sweetviz) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/dakshyadav/Desktop/DATA_SCIENCE/.venv/lib/python3.14/site-packages (from matplotlib>=3.1.3->sweetviz) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dakshyadav/Desktop/DATA_SCIENCE/.venv/lib/python3.14/site-packages (from matplotlib>=3.1.3->sweetviz) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/dakshyadav/Desktop/DATA_SCIENCE/.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.17.0)
# Using cached sweetviz-2.3.3-py3-none-any.whl (15.1 MB)
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Downloading tqdm-4.70.0-py3-none-any.whl (80 kB)
# Installing collected packages: tqdm, importlib_resources, sweetviz
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [sweetviz]2/3 [sweetviz]
# Successfully installed importlib_resources-7.1.0 sweetviz-2.3.3 tqdm-4.70.0
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import sweetviz as sv

# %%
df = pd.read_csv("titanic.csv")

df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
report = sv.analyze(df)

# Save the report as an HTML file
report.show_html("Titanic_EDA_Report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# findfont: Failed to find font weight normal, now using 500.
# Report Titanic_EDA_Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
